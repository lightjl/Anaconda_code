# %%
from importlib import reload
import MyStock as ms

reload(ms)
# Out:
# <module 'MyStock' from 'D:\\Anaconda_code\\MyStock.py'>

# %%
import tushare as ts
df = ts.forecast_data(2014,4)
# Out:
# [Getting data:]############################################################

# %%
df.head()
# Out:
#      code   name type report_date  pre_eps          range
# 0  000511  *ST烯碳   预亏  2015-04-29     0.06              0
# 1  600817  *ST宏盛   预亏  2015-04-29     0.02              0
# 2  000415   渤海金控   预降  2015-04-23     0.83  -13.5%~-11.6%
# 3  600247   ST成城   预亏  2015-04-28    -0.41              0
# 4  600408   安泰集团   预亏  2015-04-28    -0.24              0

# %%
df.pivot_table(index=['code', 'name',"report_date"], values=[ "pre_eps"])
# Out:
#                          pre_eps
# code   name report_date
# 000004 国农科技 2015-01-28   -0.0123
#             2015-04-01   -0.0123
#             2015-04-16   -0.0123
# 000005 世纪星源 2015-01-30   -0.0463
# 000006 深振业A 2015-01-09    0.5156
# 000007 全新好  2015-01-29    0.1007
#             2015-04-15    0.1007
# 000008 神州高铁 2015-01-31    0.0700
# 000010 美丽生态 2014-10-24    0.0053
# 000014 沙河股份 2015-01-16    0.1426
# 000017 深中华A 2015-01-30    2.8570
# 000018 神州长城 2015-01-30    0.0486
# 000019 深深宝A 2015-01-31    0.1740
#             2015-04-14    0.1740
# 000020 深华发A 2015-01-28   -0.0230
# 000025 特力A  2015-01-29    0.0313
# 000027 深圳能源 2015-01-23    0.5498
# 000029 深深房A 2014-10-23    0.2256
# 000032 深桑达A 2015-01-28    0.0400
# 000034 神州数码 2015-01-29    0.0500
# 000035 中国天楹 2015-01-28    5.9900
#             2015-04-15    5.9900
# 000036 华联控股 2015-01-30    0.0710
#             2015-04-08    0.0710
# 000037 深南电A 2015-01-30    0.0900
#             2015-04-15    0.0900
# ...

# %%
df17 = ts.forecast_data(2017,4)
# Out:
# [Getting data:]######################################################

# %%
df17[df17.code == '600522']
# Out:
# Empty DataFrame
# Columns: [code, name, type, report_date, pre_eps, range]
# Index: []

# %%
test = ms.MyStock()

# %%
test.research()

# %%
test.stockGDF['pe_r-c'] = test.stockGDF['price_report_date']/test.stockGDF['eps']

# %%
test.stockGDF.loc[test.stockGDF.code == '002078','nprg4'] = 27

# %%
import numpy as np
dfs_growth = test.stockGDF
dfs_growth[((np.isnan(dfs_growth.nprg4) & (dfs_growth.nprg0>25)) | (~np.isnan(dfs_growth.nprg4) & (dfs_growth.nprg4>25))) \
                                     &(dfs_growth.nprg1>25) &(dfs_growth.nprg2>25)&(dfs_growth.nprg3>25) & (dfs_growth.code == '002078')]
# Out:
#       code name0   mbrg0  nprg0     nav0   targ0    epsg0     seg0 name1  \
# 34  002078  太阳纸业  4.6736    0.0  23.9247  4.7251  44.4444  28.9797  太阳纸业
#
#      mbrg1 ...    eps  rec_report_date     nprg  pe_report_date  \
# 34 -4.0129 ...   0.42       2017-04-25  53.3837           16.51
#
#     peg_report_date price_report_date  price_now        涨幅     pe  peg
# 34             0.31             6.962      11.46  0.646079  16.21  0.3
#
# [1 rows x 66 columns]

# %%
test.stockGDF[['code','name2','peg', 'peg_report_date', 'pe', 'pe_report_date', 'eps', 'nprg', 'price_now', 'rec_report_date', 'price_report_date', '涨幅']         
              + ['nprg'+str(i) for i in range(5)]]\
[(test.stockGDF.pe_report_date < 40 ) & (test.stockGDF.pe_report_date > 10 ) ] \
.sort_values(['peg'])
# Out:
#       code name2   peg  peg_report_date     pe  pe_report_date   eps  \
# 45  300121  阳谷华泰  0.08             0.11  22.87           32.67  0.56
# 6   600816  安信信托  0.21             0.23  15.64           17.23  1.71
# 54  300267  尔康制药  0.23             0.45  15.67           30.89  0.50
# 10  002019  亿帆医药  0.24             0.30  21.20           26.63  0.64
# 47  300182  捷成股份  0.28             0.32  24.24           26.98  0.39
# 34  002078  太阳纸业  0.30             0.31  16.21           16.51  0.42
# 11  600057  象屿股份  0.42             0.62  19.02           28.20  0.36
# 19  603306  华懋科技  0.51             0.54  25.53           27.31  1.25
# 21  300432  富临精工  0.63             1.13  19.88           35.76  0.64
# 26  002450   康得新  0.69             0.77  27.50           30.65  0.60
# 13  002020  京新药业  0.72             1.14  21.52           34.26  0.33
# 9   300017  网宿科技  0.75             0.59  37.64           29.62  1.62
# 15  002271  东方雨虹  0.75             0.60  30.72           24.37  1.22
# ...

# %%
test.basics_df()
# Out:
#          name industry area      pe  outstanding  totals  totalAssets  \
# code
# 603516    N淳中     通信设备   北京   27.50         0.23    0.94     29737.55
# 300370   安控科技     电器仪表   北京  122.35         6.69    9.59    368255.25
# 603117   万林股份     仓储物流   江苏   36.11         2.82    4.62    454634.94
# 300277    海联讯     软件服务   深圳    0.00         3.34    3.35     62416.96
# 002128   露天煤业     煤炭开采   内蒙   12.43        16.34   16.34   1419173.38
# 600740   山西焦化     焦炭加工   山西  151.45         6.57    7.66   1127389.75
# 600583   海油工程     石油开采   天津   80.67        44.21   44.21   2959248.75
# 601699   潞安环能     煤炭开采   山西   16.45        29.91   29.91   6240763.50
# 600362   江西铜业        铜   江西   35.36        20.75   34.63   9657144.00
# 603356   华菱精工     机械基件   安徽   58.91         0.33    1.33     52746.38
# 601838   成都银行       银行   四川   11.75         3.61   36.12  40991660.00
# 600497   驰宏锌锗       铅锌   云南   35.17        43.10   50.91   3296117.25
# ...

# %%
test.stockGDF.merge(test.basics_df()[['pe']], left_on='code', right_index=True)
# Out:
#       code name0     mbrg0      nprg0      nav0     targ0     epsg0      seg0  \
# 0   300593   新雷能   32.2045  1554.8818   24.7699   22.1790       NaN   24.7699
# 1   002614   奥佳华   25.8694   287.5262    4.0064   19.2742  295.4545    3.8546
# 2   603579  荣泰健康   25.9892   269.4559   -8.0437   27.7160       NaN   -8.3904
# 3   601179  中国西电    4.5743   232.0633   25.2853   11.1603  159.2593   25.6805
# 4   600867  通化东宝   21.4530   200.8781    1.2569   13.2066  150.0000    1.5026
# 5   002590  万安科技   25.7184   197.3318    5.4494   12.9761  190.0000    4.6133
# 6   600816  安信信托 -100.0000   172.7590   37.1393   68.2672  159.6795   37.1393
# 7   300274  阳光电源   95.7290   148.6635   10.9263   41.8303  143.4783   10.9252
# 8   002126  银轮股份   13.6718   130.1681    8.7538   27.1628  130.7692    9.6411
# 9   300017  网宿科技   47.8880   128.5510   30.7636   41.6327  128.3582   30.7636
# 10  002019  亿帆医药    8.3562   126.2480    5.5804   -0.0522   78.7692    5.5804
# ...

# %%
df[df.index == '002078']
# Out:
#         name industry area     pe  outstanding  totals  totalAssets  \
# code
# 002078  太阳纸业       造纸   山东  16.51        25.24   25.36    2019419.0
#
#         liquidAssets  fixedAssets   reserved   ...     bvps    pb  \
# code                                           ...
# 002078     733128.19    1128489.5  120765.52   ...     3.14  2.19
#
#         timeToMarket       undp  perundp    rev  profit    gpr   npr  holders
# code
# 002078      20061116  357597.97     1.41  33.54   58.52  21.92  7.31    74370
#
# [1 rows x 22 columns]

# %%
test.stockGDF[['code','peg_report_date', 'pe_report_date', 'eps', 'nprg', 'price_now', 'rec_report_date', 'price_report_date', '涨幅']         
              + ['nprg'+str(i) for i in range(5)]][test.stockGDF.peg_report_date<0.4].describe()
# Out:
#        peg_report_date  pe_report_date        eps        nprg  price_now  \
# count        11.000000       11.000000  11.000000   11.000000  11.000000
# mean          0.211818       27.803636   0.650000  151.455300  11.801818
# std           0.128204       14.426652   0.405537   93.484958   3.663656
# min           0.000000        0.000000   0.280000   39.511400   8.050000
# 25%           0.105000       21.725000   0.405000   80.779800   8.935000
# 50%           0.220000       25.930000   0.560000  115.082700  11.460000
# 75%           0.310000       36.535000   0.640000  225.391400  13.275000
# max           0.380000       54.050000   1.710000  298.795800  20.400000
#
#        price_report_date         涨幅       nprg0       nprg1       nprg2  \
# count          11.000000  11.000000   11.000000   11.000000   11.000000
# mean           12.629000  -0.026862   61.601745  158.508318  135.140209
# std             4.033403   0.280003   45.924228  237.017158  263.325583
# ...

# %%
test.stockGDF[['code','name2','peg_report_date', 'pe_report_date', 'eps', 'nprg', 'price_now', 'rec_report_date', 'price_report_date', '涨幅']         
              + ['nprg'+str(i) for i in range(5)]].sort_values(['peg_report_date'])
# Out:
#       code name2  peg_report_date  pe_report_date   eps      nprg  price_now  \
# 30  000158  常山北明             0.00            0.00  0.28   39.5114       8.12
# 31  300253  卫宁健康             0.10           23.16  0.64  225.3914       8.05
# 32  300253  卫宁健康             0.10           23.16  0.64  225.3914       8.05
# 45  300121  阳谷华泰             0.11           32.90  0.56  298.7958      13.49
# 56  002579  中京电子             0.14           40.17  0.31  280.4336      10.20
# 6   600816  安信信托             0.22           16.75  1.71   76.1722      13.06
# 10  002019  亿帆医药             0.29           25.93  0.64   88.8034      20.40
# 48  002589  瑞康医药             0.30           54.05  1.01  177.6553      13.05
# 47  300182  捷成股份             0.32           26.98  0.39   85.3874       9.75
# 23  300237  美晨生态             0.37           42.45  0.55  115.0827      14.19
# 34  002078  太阳纸业             0.38           20.29  0.42   53.3837      11.46
# ...

# %%
test.stockGDF[['code','name2','peg_report_date', 'pe_report_date', 'eps', 'nprg', 'price_now', 'rec_report_date', 'price_report_date', '涨幅']         
              + ['nprg'+str(i) for i in range(5)]]\
[(test.stockGDF.pe_report_date < 40 ) & (test.stockGDF.pe_report_date > 10 ) & (test.stockGDF.nprg < 100 ) & (test.stockGDF.nprg0 < 100 )\
    & (test.stockGDF.nprg1 < 100 )& (test.stockGDF.nprg2 < 100 )] \
.sort_values(['peg_report_date'])
# Out:
#       code name2  peg_report_date  pe_report_date   eps     nprg  price_now  \
# 34  002078  太阳纸业             0.38           20.29  0.42  53.3837      11.46
# 19  603306  华懋科技             0.61           30.77  1.25  50.2727      26.94
# 29  000046  泛海控股             0.64           18.75  0.60  29.1792       7.92
# 15  002271  东方雨虹             0.65           26.37  1.22  40.8208      39.06
# 16  002271  东方雨虹             0.65           26.37  1.22  40.8208      39.06
# 55  000418  小天鹅A             0.69           19.05  1.86  27.5039      71.85
# 18  002573  清新环境             0.80           36.28  0.70  45.4078      16.24
# 36  002508  老板电器             0.80           36.65  1.67  45.7593      52.85
# 26  002450   康得新             0.87           34.81  0.60  39.8683      20.00
# 52  002179  中航光电             1.13           32.33  1.22  28.7020      34.72
# 38  002415  海康威视             1.19           31.04  1.23  26.1437      39.68
#
# ...

# %%
df2016 = get_data('report', 2016)
# Out:
# [Getting data:]###########################################################

# %%
df2015 = get_data('report', 2015)

# %%
df_basics = basics_df(date='2017-04-25')

# %%
df_basics.loc['603096','pe']
# Out:
# 22.61

# %%
pe('603096', '2017-04-25')
# Out:
# 22.61

# %%
date = None
saveFileNameStr = './data/basics/%s.csv' % (date)
print(saveFileNameStr)
# Out:
# ./data/basics/None.csv
